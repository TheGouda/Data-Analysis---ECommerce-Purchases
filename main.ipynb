# %% [markdown]
# # Project Title: `Ecommerce Purchases Analysis`
# ### Description: This notebook presents an analysis of ecommerce purchase data.
# ##### Dataset: https://www.kaggle.com/datasets/utkarsharya/ecommerce-purchases¶

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Data/Ecommerce Purchases') #Loading dataset into the dataframe
backup = pd.read_csv('Data/Ecommerce Purchases') #Backup dataframe

# %%
data #displays the whole dataset
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
data.head() #displays top 5 records
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
data.tail() #displays bottom 5 records
# Out:
#                                                 Address    Lot AM or PM  \
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# 9995  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/5352 ...
# 9996  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 9997  Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_7...
# 9998  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_8;...
# 9999  Mozilla/5.0 (X11; Linux i686; rv:1.9.5.20) Gec...
#
#                        Company       Credit Card CC Exp Date  \
# 9995             Randall-Sloan   342945015358701       03/22
# 9996  Hale, Collins and Wilson   210033169205009       07/25
# ...

# %%
data.head(-5) #skips bottom 5 records
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9990  75731 Molly Springs\nWest Danielle, VT 96934-5102  93 ty       PM
# 9991              PSC 8165, Box 8498\nAPO AP 60327-0346  50 dA       AM
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  40 vH       PM
# 9993  7555 Larson Locks Suite 229\nEllisburgh, MA 34...  72 jg       PM
# 9994       6276 Rojas Hollow\nLake Louis, WY 56410-7837  93 Ex       PM
#
#                                            Browser Info  \
# ...

# %%
data.tail(-5) #skips top 5 records
# Out:
#                                                 Address    Lot AM or PM  \
# 5     7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 6        93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 7     260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 8               2129 Dylan Burg\nNew Michelle, ME 28650  45 JN       PM
# 9       3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
data.dtypes #list of datatypes of each column
# Out:
# Address              object
# Lot                  object
# AM or PM             object
# Browser Info         object
# Company              object
# Credit Card           int64
# CC Exp Date          object
# CC Security Code      int64
# CC Provider          object
# Email                object
# Job                  object
# IP Address           object
# Language             object
# Purchase Price      float64
# dtype: object

# %%
data.isnull().sum() #to check the number of null values in each column
# Out:
# Address             0
# Lot                 0
# AM or PM            0
# Browser Info        0
# Company             0
# Credit Card         0
# CC Exp Date         0
# CC Security Code    0
# CC Provider         0
# Email               0
# Job                 0
# IP Address          0
# Language            0
# Purchase Price      0
# dtype: int64

# %%
print(f"The dataset has {data.shape[0]} rows and {data.shape[1]} columns")
# Out:
# The dataset has 10000 rows and 14 columns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %%
data.describe()
# Out:
#         Credit Card  CC Security Code  Purchase Price
# count  1.000000e+04      10000.000000    10000.000000
# mean   2.341374e+15        907.217800       50.347302
# std    2.256103e+15       1589.693035       29.015836
# min    6.040186e+10          0.000000        0.000000
# 25%    3.056322e+13        280.000000       25.150000
# 50%    8.699942e+14        548.000000       50.505000
# 75%    4.492298e+15        816.000000       75.770000
# max    6.012000e+15       9993.000000       99.990000

# %%
data.describe().T #Transposing for readability
# Out:
#                     count          mean           std           min  \
# Credit Card       10000.0  2.341374e+15  2.256103e+15  6.040186e+10
# CC Security Code  10000.0  9.072178e+02  1.589693e+03  0.000000e+00
# Purchase Price    10000.0  5.034730e+01  2.901584e+01  0.000000e+00
#
#                            25%           50%           75%           max
# Credit Card       3.056322e+13  8.699942e+14  4.492298e+15  6.012000e+15
# CC Security Code  2.800000e+02  5.480000e+02  8.160000e+02  9.993000e+03
# Purchase Price    2.515000e+01  5.050500e+01  7.577000e+01  9.999000e+01

# %%
#converting all the floating numbers to 2 decimal numbers

pd.options.display.float_format = "{:.2f}".format

# %%
data.describe().T
# Out:
#                     count                mean                 std  \
# Credit Card      10000.00 2341373942652652.00 2256102885223829.00
# CC Security Code 10000.00              907.22             1589.69
# Purchase Price   10000.00               50.35               29.02
#
#                             min               25%                50%  \
# Credit Card      60401860543.00 30563223611130.50 869994171540613.50
# CC Security Code           0.00            280.00             548.00
# Purchase Price             0.00             25.15              50.50
#
#                                  75%                 max
# Credit Card      4492297929116673.00 6011999761615928.00
# CC Security Code              816.00             9993.00
# Purchase Price                 75.77               99.99

# %%
data.describe(include='all')
# Out:
#                                       Address    Lot AM or PM  \
# count                                   10000  10000    10000
# unique                                  10000   9822        2
# top     PSC 5678, Box 4503\nAPO AP 94998-5546  03 dn       PM
# freq                                        1      2     5068
# mean                                      NaN    NaN      NaN
# std                                       NaN    NaN      NaN
# min                                       NaN    NaN      NaN
# 25%                                       NaN    NaN      NaN
# 50%                                       NaN    NaN      NaN
# 75%                                       NaN    NaN      NaN
# max                                       NaN    NaN      NaN
#
#                                              Browser Info      Company  \
# count                                               10000        10000
# unique                                               8287         8653
# ...

# %%
# Highest Purchase made
print(data['Purchase Price'].max())
# Out:
# 99.99

# %%
#Lowest purchase made
print(data['Purchase Price'].min())
# Out:
# 0.0

# %%
#Average purchase made
print(data['Purchase Price'].mean())
# Out:
# 50.347302

# %%
# People with English as their Language
len(data[data['Language']=='en'])
# Out:
# 1098

# %%
# People with Spanish as their Language
len(data[data['Language']=='es'])
# Out:
# 1095

# %%
#People with job title containing Scientist
len(data[data['Job'].str.contains('Scientist', case=False)]) #case=False is used to make the search case-insensitive
# Out:
# 421

# %%
# Number of peoples purchase during the AM and How many purchase during PM?
print(f"AM : {len(data[data['AM or PM'] == 'AM'])} and PM : {len(data[data['AM or PM'] == 'PM'])}")
# Out:
# AM : 4932 and PM : 5068

# %%
# Top 5 Most Popular Email providers (e.g. gmail, yahoo etc)
print(data['Email'].apply(lambda x:x.split('@')[1]).value_counts().head())
# Out:
# Email
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: count, dtype: int64
